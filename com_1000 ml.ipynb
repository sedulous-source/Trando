# %%
import pandas as pf
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install sklearn
# Out:
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
import seaborn as sns

# %%
import os

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '1000_Companies.csv', 'Untitled.ipynb']

# %%
com_10000=pf.read_csv("1000_Companies.csv")

# %%
com_1000=com_10000

# %%
com_1000
# Out:
#      R&D Spend  Administration  Marketing Spend       State        Profit
# 0    165349.20      136897.800      471784.1000    New York  192261.83000
# 1    162597.70      151377.590      443898.5300  California  191792.06000
# 2    153441.51      101145.550      407934.5400     Florida  191050.39000
# 3    144372.41      118671.850      383199.6200    New York  182901.99000
# 4    142107.34       91391.770      366168.4200     Florida  166187.94000
# ..         ...             ...              ...         ...           ...
# 995   54135.00      118451.999      173232.6695  California   95279.96251
# 996  134970.00      130390.080      329204.0228  California  164336.60550
# 997  100275.47      241926.310      227142.8200  California  413956.48000
# 998  128456.23      321652.140      281692.3200  California  333962.19000
# 999  161181.72      270939.860      295442.1700    New York  476485.43000
#
# [1000 rows x 5 columns]

# %%
plt.figure(figsize=(10,8))
sns.heatmap(com_1000.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=com_1000,y_vars="Profit",x_vars=['R&D Spend','Administration','Marketing Spend'])

# %%
x1 = com_1000.drop(com_1000.columns[[3,4]], axis=1)

# %%
x1
# Out:
#      R&D Spend  Administration  Marketing Spend
# 0    165349.20      136897.800      471784.1000
# 1    162597.70      151377.590      443898.5300
# 2    153441.51      101145.550      407934.5400
# 3    144372.41      118671.850      383199.6200
# 4    142107.34       91391.770      366168.4200
# ..         ...             ...              ...
# 995   54135.00      118451.999      173232.6695
# 996  134970.00      130390.080      329204.0228
# 997  100275.47      241926.310      227142.8200
# 998  128456.23      321652.140      281692.3200
# 999  161181.72      270939.860      295442.1700
#
# [1000 rows x 3 columns]

# %%
y1 = com_1000.drop(com_1000.columns[[0,1,2,3]], axis=1)

# %%
y1
# Out:
#            Profit
# 0    192261.83000
# 1    191792.06000
# 2    191050.39000
# 3    182901.99000
# 4    166187.94000
# ..            ...
# 995   95279.96251
# 996  164336.60550
# 997  413956.48000
# 998  333962.19000
# 999  476485.43000
#
# [1000 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x1, y1, test_size=0.33)

# %%
X_train
# Out:
#      R&D Spend  Administration  Marketing Spend
# 868   43391.00     116865.2761     152502.09220
# 18    91749.16     114175.7900     294919.57000
# 436  147448.00     132232.8879     353280.35780
# 4    142107.34      91391.7700     366168.42000
# 380    3372.00     110955.0879      75285.32239
# ..         ...             ...              ...
# 388   18192.00     113143.7730     103880.55290
# 248   81122.00     122437.5621     225304.15970
# 184   29050.00     114747.3319     124831.09350
# 543   59551.00     119251.8585     183682.85630
# 457  135965.00     130537.0261     331123.87800
#
# [670 rows x 3 columns]

# %%
X_test
# Out:
#      R&D Spend  Administration  Marketing Spend
# 801    17432.0     113031.5328      102414.1308
# 653   107750.0     126370.1064      276682.9584
# 449    27745.0     114554.6036      122313.0924
# 134    53315.0     118330.8977      171650.4773
# 527    24538.0     114080.9792      116125.1772
# ..         ...             ...              ...
# 715    15132.0     112691.8583       97976.2745
# 267    80315.0     122318.3806      223747.0510
# 378   157947.0     133783.4280      373538.2070
# 187    21265.0     113597.6077      109809.9147
# 268   116953.0     127729.2474      294440.1721
#
# [330 rows x 3 columns]

# %%
y_train
# Out:
#            Profit
# 868   86101.45602
# 18   124266.90000
# 436  174996.45320
# 4    166187.94000
# 380   51913.56964
# ..            ...
# 388   64574.16776
# 248  118334.72370
# 184   73850.06347
# 543   99906.80457
# 457  165186.62540
#
# [670 rows x 1 columns]

# %%
y_test
# Out:
#            Profit
# 801   63924.90632
# 653  141082.79440
# 449   72735.21323
# 134   94579.44358
# 527   69995.50080
# ..            ...
# 715   61960.03617
# 267  117645.31060
# 378  183965.65830
# 187   67199.40514
# 268  148944.83780
#
# [330 rows x 1 columns]

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
 reg.score(X_train, y_train)
# Out:
# 0.9371921340040825

# %%
reg.coef_
# Out:
# array([[0.45186024, 1.14096636, 0.12600261]])

# %%
reg.intercept_
# Out:
# array([-86143.01329624])

# %%
reg.predict(X_test)
# Out:
# array([[ 63603.43851621],
#        [141591.74259097],
#        [ 72508.56681948],
#        [ 94587.89696666],
#        [ 69739.36805536],
#        [164638.17674607],
#        [ 55212.94758985],
#        [105096.51825213],
#        [ 68304.25479976],
#        [ 55362.33070289],
#        [ 93604.38661718],
#        [160137.68912843],
#        [103921.31415272],
#        [106569.62485399],
#        [140789.56441171],
#        [ 93275.39856434],
#        [129356.14985291],
#        [133336.8190693 ],
#        [102304.00535059],
#        [ 72644.99750528],
#        [ 71649.39844338],
#        [ 60594.19071752],
#        [163773.82758012],
#        [ 75098.16054609],
#        [151767.92193826],
#        [114198.52133598],
#        [169980.56290785],
#        [111835.16092173],
#        [141093.51130851],
#        [ 59617.58827926],
#        [182519.23928049],
#        [ 76040.22342318],
#        [161731.68379314],
#        [ 97275.92802021],
#        [106345.98205066],
# ...

# %%
score =reg.score(X_test,y_test)
print(score*100,'%')
# Out:
# 97.73430479148166 %

# %%
y_pred = reg.predict(X_test)

# %%
df_preds = pf.DataFrame({'Actual': y_test.squeeze(), 'Predicted': y_pred.squeeze()})

# %%
df_preds
# Out:
#            Actual      Predicted
# 801   63924.90632   63603.438516
# 653  141082.79440  141591.742591
# 449   72735.21323   72508.566819
# 134   94579.44358   94587.896967
# 527   69995.50080   69739.368055
# ..            ...            ...
# 715   61960.03617   61617.421309
# 267  117645.31060  117902.011564
# 378  183965.65830  184936.135753
# 187   67199.40514   66913.179310
# 268  148944.83780  149538.401815
#
# [330 rows x 2 columns]

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_preds.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# so the actual and predicted data is almost same

# %%
Predicted= df_preds.drop(df_preds.columns[[0]], axis=1)

# %%
Predicted
# Out:
#          Predicted
# 801   63603.438516
# 653  141591.742591
# 449   72508.566819
# 134   94587.896967
# 527   69739.368055
# ..             ...
# 715   61617.421309
# 267  117902.011564
# 378  184936.135753
# 187   66913.179310
# 268  149538.401815
#
# [330 rows x 1 columns]

# %%
actual= df_preds.drop(df_preds.columns[[1]], axis=1)

# %%
actual
# Out:
#            Actual
# 801   63924.90632
# 653  141082.79440
# 449   72735.21323
# 134   94579.44358
# 527   69995.50080
# ..            ...
# 715   61960.03617
# 267  117645.31060
# 378  183965.65830
# 187   67199.40514
# 268  148944.83780
#
# [330 rows x 1 columns]

# %%
import math

# %%
MSE = np.square(np.subtract(actual,Predicted)).mean()
# Out:
# C:\Users\vinee\AppData\Local\Temp\ipykernel_10196\414132563.py:1: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# Convert one of the arguments to a NumPy array (eg 'ufunc(df1, np.asarray(df2)') to keep the current behaviour, or align manually (eg 'df1, df2 = df1.align(df2)') before passing to the ufunc to obtain the future behaviour and silence this warning.
#   MSE = np.square(np.subtract(actual,Predicted)).mean()

# %%
MSE
# Out:
# Actual    3.687731e+07
# dtype: float64
