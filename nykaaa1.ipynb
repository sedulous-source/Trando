# %%
import pandas as pf
import numpy as np
import warnings 
warnings.filterwarnings("ignore")

# %%
import seaborn as sb

# %%
import os

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'clean data (1).ipynb', 'clean data (2).ipynb', 'clean data.ipynb', 'd1.csv', 'data.csv', 'data1.csv', 'df3.csv', 'duplicate.csv', 'Heart Disease Prediction (1) (2).ipynb', 'Iris.csv', 'nykaa.ipynb', 'Nykaa_Product_Review.csv', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'visual.ipynb']

# %%
data=pf.read_csv('Nykaa_Product_Review.csv')

# %%
data
# Out:
#                            Product Id Product Brand Code   Retailer  \
# 0    b77f3da33be6e65f6183da6ada8c07ca             BZ1000  nykaa.com
# 1    f54658c5d511195b6621a640fb743b1b             BH5931  nykaa.com
# 2    cdf6b3387f8976c8e38ad150173dbb6d             BH7276  nykaa.com
# 3    424755c11c78b2b24ff13c675baf5d19             BZ1000  nykaa.com
# 4    f7f76573099db0058ef5264c35d9d02e             BZ1000  nykaa.com
# ..                                ...                ...        ...
# 620  f8d07d195abcf8adad9bc744e305876e             BZ1000  nykaa.com
# 621  295daff50e8e854436fc7ea91816590a             BZ1000  nykaa.com
# 622  42eaf0ea93e25cf422f83cb90be6ef66             BZ1000  nykaa.com
# 623  43a298f6fb694f35826da3b2fe726168             BZ1000  nykaa.com
# 624  3a5247720e93fd276bd6a797adf7629b             BZ1000  nykaa.com
#
#                                   Product Category       Product Brand  \
# 0                          Makeup > Face > Contour         ETUDE HOUSE
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product Id               625 non-null    object
#  1   Product Brand Code       625 non-null    object
#  2   Retailer                 625 non-null    object
#  3   Product Category         544 non-null    object
#  4   Product Brand            625 non-null    object
#  5   Product Name             625 non-null    object
#  6   Product Price            625 non-null    object
#  7   Product Url              610 non-null    object
#  8   Market                   625 non-null    object
#  9   Product Description      625 non-null    object
#  10  Product Currency         625 non-null    object
#  11  Product Image Url        625 non-null    object
#  12  Product Tags             610 non-null    object
#  13  Product Contents         324 non-null    object
# ...

# %%
data.describe()
# Out:
#        Product Reviews Count  Expected Brand Count
# count              563.00000            625.000000
# mean               357.20444            130.012800
# std               1062.46027            276.976406
# min                  0.00000              0.000000
# 25%                  3.00000              0.000000
# 50%                 21.00000              0.000000
# 75%                141.50000            137.000000
# max               8513.00000           2096.000000

# %%
data.isnull().sum()
# Out:
# Product Id                   0
# Product Brand Code           0
# Retailer                     0
# Product Category            81
# Product Brand                0
# Product Name                 0
# Product Price                0
# Product Url                 15
# Market                       0
# Product Description          0
# Product Currency             0
# Product Image Url            0
# Product Tags                15
# Product Contents           301
# Product Rating              69
# Product Reviews Count       62
# Expected Category Count      0
# Expected Brand Count         0
# dtype: int64

# %%
data.head()
# Out:
#                          Product Id Product Brand Code   Retailer  \
# 0  b77f3da33be6e65f6183da6ada8c07ca             BZ1000  nykaa.com
# 1  f54658c5d511195b6621a640fb743b1b             BH5931  nykaa.com
# 2  cdf6b3387f8976c8e38ad150173dbb6d             BH7276  nykaa.com
# 3  424755c11c78b2b24ff13c675baf5d19             BZ1000  nykaa.com
# 4  f7f76573099db0058ef5264c35d9d02e             BZ1000  nykaa.com
#
#                                 Product Category    Product Brand  \
# 0                        Makeup > Face > Contour      ETUDE HOUSE
# 1                          Brand > L'Oreal Paris    L'Oreal Paris
# 2                     Makeup > Face > Foundation    The Body Shop
# 3  Health & Wellness > Good for You > Super Food    True Elements
# 4                      Makeup > Lips > Lip Stain  Nykaa Cosmetics
#
#                                         Product Name Product Price  \
# 0                ETUDE HOUSE Face Color Shading - 02           600
# ...

# %%
data[data.duplicated(keep=False)]
# Out:
#                            Product Id Product Brand Code   Retailer  \
# 6    e22a7ea6c594e3e52a4dbe1eb04fd7a3             BH5825  nykaa.com
# 125  b73c701b1803640ffa157c53db729404             BZ1000  nykaa.com
# 290  e22a7ea6c594e3e52a4dbe1eb04fd7a3             BH5825  nykaa.com
# 432  b73c701b1803640ffa157c53db729404             BZ1000  nykaa.com
#
#     Product Category Product Brand  \
# 6      Brand > Nivea         Nivea
# 125              NaN         M.A.C
# 290    Brand > Nivea         Nivea
# 432              NaN         M.A.C
#
#                                           Product Name Product Price  \
# 6    NIVEA Body Lotion Oil in Lotion Rose & Argan O...           260
# 125  M.A.C Extra Dimension Skinfinish Powder - Oh, ...          3100
# 290  NIVEA Body Lotion Oil in Lotion Rose & Argan O...           260
# 432  M.A.C Extra Dimension Skinfinish Powder - Oh, ...          3100
#
#                                        Product Url Market  \
# ...

# %%
data = data.drop_duplicates(keep="first")

# %%
data
# Out:
#                            Product Id Product Brand Code   Retailer  \
# 0    b77f3da33be6e65f6183da6ada8c07ca             BZ1000  nykaa.com
# 1    f54658c5d511195b6621a640fb743b1b             BH5931  nykaa.com
# 2    cdf6b3387f8976c8e38ad150173dbb6d             BH7276  nykaa.com
# 3    424755c11c78b2b24ff13c675baf5d19             BZ1000  nykaa.com
# 4    f7f76573099db0058ef5264c35d9d02e             BZ1000  nykaa.com
# ..                                ...                ...        ...
# 620  f8d07d195abcf8adad9bc744e305876e             BZ1000  nykaa.com
# 621  295daff50e8e854436fc7ea91816590a             BZ1000  nykaa.com
# 622  42eaf0ea93e25cf422f83cb90be6ef66             BZ1000  nykaa.com
# 623  43a298f6fb694f35826da3b2fe726168             BZ1000  nykaa.com
# 624  3a5247720e93fd276bd6a797adf7629b             BZ1000  nykaa.com
#
#                                   Product Category       Product Brand  \
# 0                          Makeup > Face > Contour         ETUDE HOUSE
# ...

# %%
data1=data.fillna('NaN')

# %%
data1
# Out:
#                            Product Id Product Brand Code   Retailer  \
# 0    b77f3da33be6e65f6183da6ada8c07ca             BZ1000  nykaa.com
# 1    f54658c5d511195b6621a640fb743b1b             BH5931  nykaa.com
# 2    cdf6b3387f8976c8e38ad150173dbb6d             BH7276  nykaa.com
# 3    424755c11c78b2b24ff13c675baf5d19             BZ1000  nykaa.com
# 4    f7f76573099db0058ef5264c35d9d02e             BZ1000  nykaa.com
# ..                                ...                ...        ...
# 620  f8d07d195abcf8adad9bc744e305876e             BZ1000  nykaa.com
# 621  295daff50e8e854436fc7ea91816590a             BZ1000  nykaa.com
# 622  42eaf0ea93e25cf422f83cb90be6ef66             BZ1000  nykaa.com
# 623  43a298f6fb694f35826da3b2fe726168             BZ1000  nykaa.com
# 624  3a5247720e93fd276bd6a797adf7629b             BZ1000  nykaa.com
#
#                                   Product Category       Product Brand  \
# 0                          Makeup > Face > Contour         ETUDE HOUSE
# ...

# %%
data2=data.dropna(subset=['Product Category','Product Url','Product Tags','Product Rating','Product Reviews Count'])

# %%
data2
# Out:
#                            Product Id Product Brand Code   Retailer  \
# 0    b77f3da33be6e65f6183da6ada8c07ca             BZ1000  nykaa.com
# 1    f54658c5d511195b6621a640fb743b1b             BH5931  nykaa.com
# 2    cdf6b3387f8976c8e38ad150173dbb6d             BH7276  nykaa.com
# 3    424755c11c78b2b24ff13c675baf5d19             BZ1000  nykaa.com
# 4    f7f76573099db0058ef5264c35d9d02e             BZ1000  nykaa.com
# ..                                ...                ...        ...
# 618  fe19790da9d93ff9f431a4b56320f3b4             BZ1000  nykaa.com
# 620  f8d07d195abcf8adad9bc744e305876e             BZ1000  nykaa.com
# 621  295daff50e8e854436fc7ea91816590a             BZ1000  nykaa.com
# 623  43a298f6fb694f35826da3b2fe726168             BZ1000  nykaa.com
# 624  3a5247720e93fd276bd6a797adf7629b             BZ1000  nykaa.com
#
#                                   Product Category    Product Brand  \
# 0                          Makeup > Face > Contour      ETUDE HOUSE
# ...

# %%
data2.to_csv('data1.csv')

# %%
data2.isnull().sum()
# Out:
# Product Id                   0
# Product Brand Code           0
# Retailer                     0
# Product Category             0
# Product Brand                0
# Product Name                 0
# Product Price                0
# Product Url                  0
# Market                       0
# Product Description          0
# Product Currency             0
# Product Image Url            0
# Product Tags                 0
# Product Contents           233
# Product Rating               0
# Product Reviews Count        0
# Expected Category Count      0
# Expected Brand Count         0
# dtype: int64

# %%
data2.drop('Market', inplace=True, axis=1)

# %%
data2
# Out:
#                            Product Id Product Brand Code   Retailer  \
# 0    b77f3da33be6e65f6183da6ada8c07ca             BZ1000  nykaa.com
# 1    f54658c5d511195b6621a640fb743b1b             BH5931  nykaa.com
# 2    cdf6b3387f8976c8e38ad150173dbb6d             BH7276  nykaa.com
# 3    424755c11c78b2b24ff13c675baf5d19             BZ1000  nykaa.com
# 4    f7f76573099db0058ef5264c35d9d02e             BZ1000  nykaa.com
# ..                                ...                ...        ...
# 618  fe19790da9d93ff9f431a4b56320f3b4             BZ1000  nykaa.com
# 620  f8d07d195abcf8adad9bc744e305876e             BZ1000  nykaa.com
# 621  295daff50e8e854436fc7ea91816590a             BZ1000  nykaa.com
# 623  43a298f6fb694f35826da3b2fe726168             BZ1000  nykaa.com
# 624  3a5247720e93fd276bd6a797adf7629b             BZ1000  nykaa.com
#
#                                   Product Category    Product Brand  \
# 0                          Makeup > Face > Contour      ETUDE HOUSE
# ...

# %%
data2.drop('Product Image Url', inplace=True, axis=1)

# %%
data2
# Out:
#                            Product Id Product Brand Code   Retailer  \
# 0    b77f3da33be6e65f6183da6ada8c07ca             BZ1000  nykaa.com
# 1    f54658c5d511195b6621a640fb743b1b             BH5931  nykaa.com
# 2    cdf6b3387f8976c8e38ad150173dbb6d             BH7276  nykaa.com
# 3    424755c11c78b2b24ff13c675baf5d19             BZ1000  nykaa.com
# 4    f7f76573099db0058ef5264c35d9d02e             BZ1000  nykaa.com
# ..                                ...                ...        ...
# 618  fe19790da9d93ff9f431a4b56320f3b4             BZ1000  nykaa.com
# 620  f8d07d195abcf8adad9bc744e305876e             BZ1000  nykaa.com
# 621  295daff50e8e854436fc7ea91816590a             BZ1000  nykaa.com
# 623  43a298f6fb694f35826da3b2fe726168             BZ1000  nykaa.com
# 624  3a5247720e93fd276bd6a797adf7629b             BZ1000  nykaa.com
#
#                                   Product Category    Product Brand  \
# 0                          Makeup > Face > Contour      ETUDE HOUSE
# ...

# %%
data2
# Out:
#                            Product Id Product Brand Code   Retailer  \
# 0    b77f3da33be6e65f6183da6ada8c07ca             BZ1000  nykaa.com
# 1    f54658c5d511195b6621a640fb743b1b             BH5931  nykaa.com
# 2    cdf6b3387f8976c8e38ad150173dbb6d             BH7276  nykaa.com
# 3    424755c11c78b2b24ff13c675baf5d19             BZ1000  nykaa.com
# 4    f7f76573099db0058ef5264c35d9d02e             BZ1000  nykaa.com
# ..                                ...                ...        ...
# 618  fe19790da9d93ff9f431a4b56320f3b4             BZ1000  nykaa.com
# 620  f8d07d195abcf8adad9bc744e305876e             BZ1000  nykaa.com
# 621  295daff50e8e854436fc7ea91816590a             BZ1000  nykaa.com
# 623  43a298f6fb694f35826da3b2fe726168             BZ1000  nykaa.com
# 624  3a5247720e93fd276bd6a797adf7629b             BZ1000  nykaa.com
#
#                                   Product Category    Product Brand  \
# 0                          Makeup > Face > Contour      ETUDE HOUSE
# ...

# %%
(data2['Retailer'] == data2['Retailer'][0]).all()
# Out:
# True

# %%
data2.drop('Retailer', inplace=True, axis=1)

# %%
data2
# Out:
#                            Product Id Product Brand Code  \
# 0    b77f3da33be6e65f6183da6ada8c07ca             BZ1000
# 1    f54658c5d511195b6621a640fb743b1b             BH5931
# 2    cdf6b3387f8976c8e38ad150173dbb6d             BH7276
# 3    424755c11c78b2b24ff13c675baf5d19             BZ1000
# 4    f7f76573099db0058ef5264c35d9d02e             BZ1000
# ..                                ...                ...
# 618  fe19790da9d93ff9f431a4b56320f3b4             BZ1000
# 620  f8d07d195abcf8adad9bc744e305876e             BZ1000
# 621  295daff50e8e854436fc7ea91816590a             BZ1000
# 623  43a298f6fb694f35826da3b2fe726168             BZ1000
# 624  3a5247720e93fd276bd6a797adf7629b             BZ1000
#
#                                   Product Category    Product Brand  \
# 0                          Makeup > Face > Contour      ETUDE HOUSE
# 1                            Brand > L'Oreal Paris    L'Oreal Paris
# 2                       Makeup > Face > Foundation    The Body Shop
# ...

# %%
(data2['Product Currency'] == data2['Product Currency'][0]).all()
# Out:
# True

# %%
data2.drop('Product Currency', inplace=True, axis=1)

# %%
data2
# Out:
#                            Product Id Product Brand Code  \
# 0    b77f3da33be6e65f6183da6ada8c07ca             BZ1000
# 1    f54658c5d511195b6621a640fb743b1b             BH5931
# 2    cdf6b3387f8976c8e38ad150173dbb6d             BH7276
# 3    424755c11c78b2b24ff13c675baf5d19             BZ1000
# 4    f7f76573099db0058ef5264c35d9d02e             BZ1000
# ..                                ...                ...
# 618  fe19790da9d93ff9f431a4b56320f3b4             BZ1000
# 620  f8d07d195abcf8adad9bc744e305876e             BZ1000
# 621  295daff50e8e854436fc7ea91816590a             BZ1000
# 623  43a298f6fb694f35826da3b2fe726168             BZ1000
# 624  3a5247720e93fd276bd6a797adf7629b             BZ1000
#
#                                   Product Category    Product Brand  \
# 0                          Makeup > Face > Contour      ETUDE HOUSE
# 1                            Brand > L'Oreal Paris    L'Oreal Paris
# 2                       Makeup > Face > Foundation    The Body Shop
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data2.isnull().sum()
# Out:
# Product Id                   0
# Product Brand Code           0
# Product Category             0
# Product Brand                0
# Product Name                 0
# Product Price                0
# Product Url                  0
# Product Description          0
# Product Tags                 0
# Product Contents           233
# Product Rating               0
# Product Reviews Count        0
# Expected Category Count      0
# Expected Brand Count         0
# dtype: int64

# %%
data2.max()
# Out:
# Product Id                                  ffaab03155d236234f17414bf4eb4e7b
# Product Brand Code                                                    BZ1000
# Product Category                              Skin > Toners > Toners & Mists
# Product Brand                                                        theBalm
# Product Name                            theBalm Shadow And Blush - CabanaBoy
# Product Price                                                            999
# Product Url                    https://www.nykaa.com/c/p/989015?skuId=785724
# Product Description        â€œLipstick is happiness in a tube!â€ - Charl...
# Product Tags               theBalm Shadow And Blush - CabanaBoy , Makeup ...
# Product Rating                                                             5
# Product Reviews Count                                                 8513.0
# Expected Category Count                                                  996
# ...

# %%
d1=(data2['Product Brand'].value_counts())

# %%
d1
# Out:
# Nykaa Cosmetics    17
# Himalaya           17
# Lakme              14
# Biotique           11
# Nykaa Naturals     11
#                    ..
# Axe                 1
# TONYMOLY            1
# Glamglow            1
# Dermalogica         1
# BOLLYGLOW           1
# Name: Product Brand, Length: 211, dtype: int64

# %% [markdown]
# # find max product brand

# %%
max_productbrand=d1.head()

# %%
max_productbrand
# Out:
# Nykaa Cosmetics    17
# Himalaya           17
# Lakme              14
# Biotique           11
# Nykaa Naturals     11
# Name: Product Brand, dtype: int64

# %%
data_dict = {'Nykaa Cosmetics':17, 'Himalaya':17, 'Lakme':14,'Biotique':11,'Nykaa Naturals':11}
product_brand = list(data_dict.keys())
no_of_occurence = list(data_dict.values())
fig = plt.figure(figsize = (10, 5))
plt.bar(product_brand, no_of_occurence, color ='green',
        width = 0.5)
plt.xlabel("product brand")
plt.ylabel("no of occurence")
plt.title("product brand bar graph")
plt.show()

# %%
d1.tail()
# Out:
# Axe            1
# TONYMOLY       1
# Glamglow       1
# Dermalogica    1
# BOLLYGLOW      1
# Name: Product Brand, dtype: int64

# %%
data_dict = {'Axe':1, 'TONYMOLY':1, 'Glamglow':1,'Dermalogica':1,'BOLLYGLOW':1}
product_brand = list(data_dict.keys())
no_of_occurence = list(data_dict.values())
fig = plt.figure(figsize = (10, 5))
plt.bar(product_brand, no_of_occurence, color ='green',
        width = 0.5)
plt.xlabel("product brand")
plt.ylabel("no of occurence")
plt.title("product brand bar graph")
plt.show()

# %%
d1=(data2['Product Category'].value_counts())

# %%
d1
# Out:
# Makeup > Lips > Lipstick                              22
# Makeup > Face > Blush                                 15
# Makeup > Lips > Liquid Lipstick                       14
# Makeup > Nails > Nail Polish                          13
# Skin > Moisturizers > Face Moisturizer & Day Cream    12
#                                                       ..
# Skin > Toners > Toners & Mists                         1
# Men's Store > Skin Care > Moisturizers                 1
# Hair > Shop By Concern > Split Ends                    1
# Nykaa Luxe > Skin > Face > Toner                       1
# Makeup > Tools & Brushes > Makeup Pouches              1
# Name: Product Category, Length: 159, dtype: int64

# %%
d1.head()
# Out:
# Makeup > Lips > Lipstick                              22
# Makeup > Face > Blush                                 15
# Makeup > Lips > Liquid Lipstick                       14
# Makeup > Nails > Nail Polish                          13
# Skin > Moisturizers > Face Moisturizer & Day Cream    12
# Name: Product Category, dtype: int64

# %%
data_dict = {'Makeup > Lips > Lipstick':22, 'Makeup > Face > Blush':15, 'Makeup > Lips > Liquid Lipstick':14,'Makeup > Nails > Nail Polish':13,'Skin > Moisturizers > Face Moisturizer & Day Cream':12}
product_cat = list(data_dict.keys())
no_of_occurence = list(data_dict.values())
fig = plt.figure(figsize = (20, 5))
plt.bar(product_cat, no_of_occurence, color ='green',
        width = 0.5)
plt.xlabel("product Category")
plt.ylabel("no of occurence")
plt.title("product categroy bar graph")
plt.show()

# %%
d1.tail()
# Out:
# Skin > Toners > Toners & Mists               1
# Men's Store > Skin Care > Moisturizers       1
# Hair > Shop By Concern > Split Ends          1
# Nykaa Luxe > Skin > Face > Toner             1
# Makeup > Tools & Brushes > Makeup Pouches    1
# Name: Product Category, dtype: int64

# %%
d1=(data2['Product Price'])

# %%
d1
# Out:
# 0       600
# 1       454
# 2      1395
# 3       175
# 4       539
#        ...
# 618     274
# 620    1000
# 621     665
# 623     675
# 624    1100
# Name: Product Price, Length: 485, dtype: object

# %%
df3 = data2[["Product Price","Product Brand Code"]]

# %%
# Out:
#     Product Price Product Brand Code
# 0             600             BZ1000
# 1             454             BH5931
# 2            1395             BH7276
# 3             175             BZ1000
# 4             539             BZ1000
# ..            ...                ...
# 618           274             BZ1000
# 620          1000             BZ1000
# 621           665             BZ1000
# 623           675             BZ1000
# 624          1100             BZ1000
#
# [485 rows x 2 columns]

# %%
df4 = df3.sort_values(['Product Price'])

# %%
df4
# Out:
#     Product Price Product Brand Code
# 49            100             BH0156
# 212           100             BZ1000
# 91            100             BZ1000
# 620          1000             BZ1000
# 501          1020             BZ1000
# ..            ...                ...
# 348           990             BH1119
# 273           995             BH7920
# 457           995             BH0283
# 306           999             BZ1000
# 265           999             BZ1000
#
# [485 rows x 2 columns]

# %%
df4.head(100)
# Out:
#     Product Price Product Brand Code
# 49            100             BH0156
# 212           100             BZ1000
# 91            100             BZ1000
# 620          1000             BZ1000
# 501          1020             BZ1000
# ..            ...                ...
# 382           180             BZ1000
# 180           180             BZ1000
# 16           1800             BZ1000
# 202          1800             BH1118
# 383           185             BZ1000
#
# [100 rows x 2 columns]

# %%
d6=df4.tail()

# %%
d6
# Out:
#     Product Price Product Brand Code
# 348           990             BH1119
# 273           995             BH7920
# 457           995             BH0283
# 306           999             BZ1000
# 265           999             BZ1000

# %%
data2
# Out:
#                            Product Id Product Brand Code  \
# 0    b77f3da33be6e65f6183da6ada8c07ca             BZ1000
# 1    f54658c5d511195b6621a640fb743b1b             BH5931
# 2    cdf6b3387f8976c8e38ad150173dbb6d             BH7276
# 3    424755c11c78b2b24ff13c675baf5d19             BZ1000
# 4    f7f76573099db0058ef5264c35d9d02e             BZ1000
# ..                                ...                ...
# 618  fe19790da9d93ff9f431a4b56320f3b4             BZ1000
# 620  f8d07d195abcf8adad9bc744e305876e             BZ1000
# 621  295daff50e8e854436fc7ea91816590a             BZ1000
# 623  43a298f6fb694f35826da3b2fe726168             BZ1000
# 624  3a5247720e93fd276bd6a797adf7629b             BZ1000
#
#                                   Product Category    Product Brand  \
# 0                          Makeup > Face > Contour      ETUDE HOUSE
# 1                            Brand > L'Oreal Paris    L'Oreal Paris
# 2                       Makeup > Face > Foundation    The Body Shop
# ...

# %%
df3 = data2[["Product Price","Product cat"]]

# %% [markdown]
# ###

# %%
df3
# Out:
#     Product Price    Product Brand
# 0             600      ETUDE HOUSE
# 1             454    L'Oreal Paris
# 2            1395    The Body Shop
# 3             175    True Elements
# 4             539  Nykaa Cosmetics
# ..            ...              ...
# 618           274           Jovees
# 620          1000             Orly
# 621           665        BOLLYGLOW
# 623           675        L.A. Girl
# 624          1100            M.A.C
#
# [485 rows x 2 columns]

# %%
df3.sort_values('Product Price', inplace=True)

# %%
df3
# Out:
#     Product Price   Product Brand
# 49            100          Disney
# 212           100        TONYMOLY
# 91            100  Nykaa Naturals
# 620          1000            Orly
# 501          1020     Big Muscles
# ..            ...             ...
# 348           990           Murad
# 273           995         Chambor
# 457           995           Lakme
# 306           999      Kay Beauty
# 265           999      Kay Beauty
#
# [485 rows x 2 columns]

# %%
df3.to_csv('df7.csv')

# %%
convert_dict = {'Product Price': float,
                
                }
 
df3 = df3.astype(convert_dict)

# %%
df3
# Out:
#      Product Price   Product Brand
# 49           100.0          Disney
# 212          100.0        TONYMOLY
# 91           100.0  Nykaa Naturals
# 620         1000.0            Orly
# 501         1020.0     Big Muscles
# ..             ...             ...
# 348          990.0           Murad
# 273          995.0         Chambor
# 457          995.0           Lakme
# 306          999.0      Kay Beauty
# 265          999.0      Kay Beauty
#
# [485 rows x 2 columns]

# %%
df8=df3.sort_values(by="Product Price",ascending=False )

# %%
df8
# Out:
#      Product Price   Product Brand
# 496         7900.0     Bobbi Brown
# 18          7000.0         CADIVEU
# 388         7000.0         CADIVEU
# 109         6125.0        Guerlain
# 349         5800.0      L'Occitane
# ..             ...             ...
# 605           41.0        Himalaya
# 115           40.0       KamaSutra
# 87            33.0        Himalaya
# 448           32.0           Liril
# 486           25.0  Godrej Protekt
#
# [485 rows x 2 columns]

# %%
df8.head(100)
# Out:
#      Product Price      Product Brand
# 496         7900.0        Bobbi Brown
# 18          7000.0            CADIVEU
# 388         7000.0            CADIVEU
# 109         6125.0           Guerlain
# 349         5800.0         L'Occitane
# ..             ...                ...
# 334         1350.0  Makeup Revolution
# 575         1310.0     Ohria Ayurveda
# 221         1300.0      CiatÃ© London
# 44          1290.0        Kiko Milano
# 96          1250.0       Estee Lauder
#
# [100 rows x 2 columns]

# %%
df9= data2[["Product Price","Product Category"]]

# %%
df9
# Out:
#     Product Price                               Product Category
# 0             600                        Makeup > Face > Contour
# 1             454                          Brand > L'Oreal Paris
# 2            1395                     Makeup > Face > Foundation
# 3             175  Health & Wellness > Good for You > Super Food
# 4             539                      Makeup > Lips > Lip Stain
# ..            ...                                            ...
# 618           274     Natural > Types of Skin > Combination Skin
# 620          1000                   Makeup > Nails > Nail Polish
# 621           665            Makeup > Eyes > Under Eye Concealer
# 623           675            Makeup > Makeup Kits > Eye Palettes
# 624          1100  Makeup > Makeup Kits > Customize Your Palette
#
# [485 rows x 2 columns]

# %%
convert_dict = {'Product Price': float,
                
                }
 
df9 = df9.astype(convert_dict)

# %%
df9
# Out:
#      Product Price                               Product Category
# 0            600.0                        Makeup > Face > Contour
# 1            454.0                          Brand > L'Oreal Paris
# 2           1395.0                     Makeup > Face > Foundation
# 3            175.0  Health & Wellness > Good for You > Super Food
# 4            539.0                      Makeup > Lips > Lip Stain
# ..             ...                                            ...
# 618          274.0     Natural > Types of Skin > Combination Skin
# 620         1000.0                   Makeup > Nails > Nail Polish
# 621          665.0            Makeup > Eyes > Under Eye Concealer
# 623          675.0            Makeup > Makeup Kits > Eye Palettes
# 624         1100.0  Makeup > Makeup Kits > Customize Your Palette
#
# [485 rows x 2 columns]

# %%
df10=df9.sort_values(by="Product Category",ascending=False )

# %%
df10
# Out:
#      Product Price                         Product Category
# 208         1400.0           Skin > Toners > Toners & Mists
# 506          135.0         Skin > Sun Care > Body Sunscreen
# 456           89.0  Skin > Shop By Concern > Sun Protection
# 95           295.0    Skin > Shop By Concern > Skin Dryness
# 235           99.0    Skin > Shop By Concern > Skin Dryness
# ..             ...                                      ...
# 217           72.0                         Brand > Himalaya
# 580           84.0                         Brand > Himalaya
# 37            49.0                         Brand > Biotique
# 439           49.0                         Brand > Biotique
# 132           99.0                         Brand > Biotique
#
# [485 rows x 2 columns]

# %%
d12=df10.groupby('Product Category')['Product Price'].mean()

# %%
d12
# Out:
# Product Category
# Brand > Biotique                               65.666667
# Brand > Himalaya                               82.857143
# Brand > L'Oreal Paris                         269.500000
# Brand > Lakme                                 529.142857
# Brand > Lotus Herbals                         142.000000
#                                                 ...
# Skin > Shop By Concern > Skin Brightening     595.571429
# Skin > Shop By Concern > Skin Dryness         406.444444
# Skin > Shop By Concern > Sun Protection        89.000000
# Skin > Sun Care > Body Sunscreen              135.000000
# Skin > Toners > Toners & Mists               1400.000000
# Name: Product Price, Length: 159, dtype: float64

# %%
A = pf.DataFrame(d12)

# %%
A
# Out:
#                                            Product Price
# Product Category
# Brand > Biotique                               65.666667
# Brand > Himalaya                               82.857143
# Brand > L'Oreal Paris                         269.500000
# Brand > Lakme                                 529.142857
# Brand > Lotus Herbals                         142.000000
# ...                                                  ...
# Skin > Shop By Concern > Skin Brightening     595.571429
# Skin > Shop By Concern > Skin Dryness         406.444444
# Skin > Shop By Concern > Sun Protection        89.000000
# Skin > Sun Care > Body Sunscreen              135.000000
# Skin > Toners > Toners & Mists               1400.000000
#
# [159 rows x 1 columns]

# %%
df10=A.sort_values(by="Product Price",ascending=False )

# %% [markdown]
# df10

# %%
df10
# Out:
#                                                Product Price
# Product Category
# Makeup > Face > BB & CC Cream                    7900.000000
# Hair > Shop By Hair Type > Straight              7000.000000
# Nykaa Luxe > Fragrance > Colognes                5050.000000
# Fragrance > Men > Perfumes (EDT & EDP)           4416.333333
# Nykaa Luxe > Makeup > Palettes > Eye Palette     4300.000000
# ...                                                      ...
# Natural > Makeup > Lip Balm & Gloss                48.000000
# Mom & Baby > Baby Care > Wipes & Buds              44.000000
# Health & Wellness > Sexual Wellness > Condoms      40.000000
# Skin > Body Care > Soaps                           38.500000
# Personal Care > Hands & Feet > Hand Sanitizer      25.000000
#
# [159 rows x 1 columns]

# %%
df14=df10.head(10)

# %%
df14
# Out:
#                                               Product Price
# Product Category
# Makeup > Face > BB & CC Cream                   7900.000000
# Hair > Shop By Hair Type > Straight             7000.000000
# Nykaa Luxe > Fragrance > Colognes               5050.000000
# Fragrance > Men > Perfumes (EDT & EDP)          4416.333333
# Nykaa Luxe > Makeup > Palettes > Eye Palette    4300.000000
# Skin > Moisturizers > BB & CC Cream             3850.000000
# Nykaa Luxe > Shop by Concern > Anti-Ageing      3732.500000
# Nykaa Luxe > Fragrance > Perfumes (EDP/EDT)     3679.000000
# Men's Store > Gifts @ Nykaa                     3487.400000
# Nykaa Luxe > Makeup > Lips > Lipstick           3150.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [150], in <cell line: 1>()
# ----> 1 boxplot = df14.boxplot(column=['Product Category', 'Product Price'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:511, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     494 @Substitution(backend=_backend_doc)
#     495 @Appender(_boxplot_doc)
#     496 def boxplot_frame(
#    (...)
#     508     **kwargs,
#     509 ):
#     510     plot_backend = _get_plot_backend(backend)
# --> 511     return plot_backend.boxplot_frame(
#     512         self,
#     513         column=column,
#     514         by=by,
#     515         ax=ax,
#     516         fontsize=fontsize,
#     517         rot=rot,
#     518         grid=grid,
#     519         figsize=figsize,
# ...

# %%
df15 = data2[["Product Brand","Product Rating"]]

# %%
df15
# Out:
#        Product Brand Product Rating
# 0        ETUDE HOUSE            4.6
# 1      L'Oreal Paris            4.3
# 2      The Body Shop            4.4
# 3      True Elements              5
# 4    Nykaa Cosmetics              4
# ..               ...            ...
# 618           Jovees            4.5
# 620             Orly            3.5
# 621        BOLLYGLOW            3.3
# 623        L.A. Girl            4.3
# 624            M.A.C            4.9
#
# [485 rows x 2 columns]

# %%
df16=df15.sort_values(by="Product Rating",ascending=False )

# %%
df16
# Out:
#           Product Brand Product Rating
# 131     Neemli Naturals              5
# 278          Lime Crime              5
# 468        Issey Miyake              5
# 296         MuscleBlaze              5
# 32        Jiva Ayurveda              5
# ..                  ...            ...
# 138             IsaDora              2
# 147         First Water              2
# 116  As-It-Is Nutrition              2
# 191     Paese Cosmetics              2
# 216        Ellement Co.              1
#
# [485 rows x 2 columns]

# %%
df16.head(50)
# Out:
#          Product Brand Product Rating
# 131    Neemli Naturals              5
# 278         Lime Crime              5
# 468       Issey Miyake              5
# 296        MuscleBlaze              5
# 32       Jiva Ayurveda              5
# 446         Lime Crime              5
# 445               Zerb              5
# 307           Burberry              5
# 433    Allin Exporters              5
# 431               Note              5
# 421          Silkberry              5
# 418               Plix              5
# 411             Niconi              5
# 408         L'Occitane              5
# 325      SSCPL Herbals              5
# 67   Charlotte Tilbury              5
# 335            Dunhill              5
# 391                OXY              5
# 51                DIOR              5
# 388            CADIVEU              5
# 362       Tea Treasure              5
# 361           KOCOSTAR              5
# 358              Spinz              5
# 354              Tjori              5
# ...
